# %% [markdown]
# # 함수(Function)

# %%
result = len('hello python')
print(result)
# Out:
# 12

# %% [markdown]
# *   **함수(function)**: 기능을 수행하는 코드 블록.
# *   **인수(argument)**: 함수를 호출할 때 함수에게 전달하는 값.
# *   **매개변수(parameter)**: 아규먼트를 저장하기 위해서 함수 선언부에서 선언하는 변수.
# *   **반환값(return value)**: 함수가 기능을 수행하고 그 결과로 함수를 호출한 곳 되돌려 주는 값.
#     *   함수에 따라서 반환값이 있는 함수도 있고, 반환값이 없는 함수도 있음.

# %% [markdown]
# # 함수 선언(정의)
#
# ```
# def function_name([parameter, ...]):
#     ["""문서 주석(documentation comments)"""]
#     함수가 수행할 코드 블록
#     [return 반환값]
# ```
#
# *   반환값이 없는 함수는 return 문장을  생략하거나, return None 문장을 사용할 수 있음.
# *   return 문장의 의미:
#     *   함수 종료
#     *   함수를 호출한 곳에 값을 되돌려 줌.

# %%
def subtract(x, y):
    """숫자 x, y 를 전달받아서 x - y 를 리턴하는 함수."""
    return x - y

# %%
result = subtract(1, 2)
print(result)
# Out:
# -1

# %% [markdown]
# ## 값을 반환하지 않는 함수

# %%
def repeat_massage(msg, n):
    """
    msg를 n번 반복해서 출력.
    @param msg - 출력할 문자열.
    @param n   - 반복할 횟수. 0 또는 양의 정수
    """
    for _ in range(n):
        print(msg)

    return None

# %%
repeat_massage('안녕하세요', 4)
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
repeat_massage('hello' , 3)
# Out:
# hello
# hello
# hello

# %% [markdown]
# ## 2개 이상의 값을 반환하는 함수

# %%
def plus_and_minus(x, y):
    """
    x + y, x - y를 리턴.

    @param x - 숫자 타입(int 또는 float)
    @param y - 숫자 타입(int 또는 float)
    @return x + y, x - y

    """

    # return ret_value1, ret_value2, ...
    return x + y,  x - y

# %%
a, b = plus_and_minus(1, 2)
print(f'a = {a}, b = {b}')
# Out:
# a = 3, b = -1

# %%
result = plus_and_minus(3, 4)
print(type(result)) # result: 리턴 값들을 저장하는 튜플.
print(result)
# Out:
# <class 'tuple'>
# (7, -1)

# %% [markdown]
# ## 연습문제 1.
#
# *   함수 이름: make_list
# *   기능: [start. end) 범위의 정수 난수 n개를 아이템으로 갖는 리스트를 리턴
# *   파라미터: start(정수), end(정수), n(0 또는 양의 정수)
# *   리턴: 리스트

# %%
import random

# %%
def make_list(x,y,n):
    """
    [start. end) 범위의 정수 난수 n개를 아이템으로 갖는 리스트를 리턴
    @param x: start(int)
    @param y: end(int)
    @param n: 0 or int > 0
    @return list
    """
    # make_list1 = []
    # for i in range(n):
    #     make_list1.append(random.randrange(x,y))

    make_list1 = [random.randrange(x,y) for _ in range(n)]

    return make_list1

# %%
my_list = make_list(0,2,10)
my_list
# Out:
# [0, 0, 0, 1, 0, 0, 0, 0, 0, 1]

# %% [markdown]
# ## 연습문제 2.
#
# *   함수 이름: calculate_sum
# *   기능: 숫자(정수, 실수)들을 원소로 갖는 리스트를 전달받아서, 그 리스트의 모든 원소들의 합계를 리턴.
# *   파라미터: array(리스트)
# *   리턴: 리스트 원소들의 합계.

# %%
def calculate_sum(array):
    """
    숫자(정수, 실수)들을 원소로 갖는 리스트를 전달받아서, 그 리스트의 모든 원소들의 합계를 리턴.
    @param array: list which is consist of int or float
    @return: sum of array
    """
    return sum(array)

# %%
my_sum = calculate_sum([1,2,3,4])
my_sum

# %%
# 오쌤
def calculate_sum(array):
    """
    숫자(정수, 실수)들을 원소로 갖는 리스트를 전달받아서, 그 리스트의 모든 원소들의 합계를 리턴.
    @param array: list which is consist of int or float
    @return: sum of array
    """
    result = 0
    for x in array:
        result += x

    return result

# %%
my_list = make_list(1,10,5)
print(my_list)
result = calculate_sum(my_list)
print(result)
# Out:
# [1, 2, 3, 1, 1]
# 8

# %% [markdown]
# ## 연습문제 3.
#
# *   함수 이름: calculate_mean
# *   기능: 숫자들을 원소로 갖는 리스트의 원소들의 평균을 리턴.
# *   파라미터: array(리스트)
# *   리턴: 리스트 원소들의 평균.

# %%
def calculate_mean(array):
    """
    숫자(정수, 실수)들을 원소로 갖는 리스트를 전달받아서, 그 리스트의 모든 원소들의 평균을 리턴.
    @param array: list which is consist of int or float
    @return: mean of array
    """
    return sum(array) / len(array)

# %%
my_mean = calculate_mean([1,2,3,4,5])
print(my_mean)
# Out:
# 3.0

# %% [markdown]
# ## 연습문제 4.
#
# *   함수 이름: find_min_and_max
# *   기능: 숫자들을 원소로 갖는 리스트를 아규먼트로 전달받아서, 리스트의 최솟값과 최댓값을 리턴.
# *   파라미터: 숫자들의 리스트.
# *   리턴: 리스트의 최솟값과 최댓값.

# %%
def find_min_and_max(array):
    """
    숫자들을 원소로 갖는 리스트를 아규먼트로 전달받아서, 리스트의 최솟값과 최댓값을 리턴.
    @param array: list which is consist of int or float
    @return: max and min of array
    """
    return max(array), min(array)

# %%
my_min_max = find_min_and_max([1,2,3,4,5,6,7])
print(my_min_max)
# Out:
# (7, 1)

# %% [markdown]
# # Default Argument(기본 아규먼트)
#
# *   함수를 선언할 때 파라미터에 설정하는 기본값.
#     *   default parameter: 기본값이 설정된 파라미터(매개변수)
# *   함수를 호출할 때 default parameter에 아규먼트를 전달하지 않으면 default 아규먼트가 기본값으로 사용됨.
# *   함수를 호출할 때 default parameter에 아규먼트를 전달하면, 기본값 대신 전달한 아규먼트가 사용됨.

# %%
print('안녕', 'hello', '파이썬', 'python')
# Out:
# 안녕 hello 파이썬 python

# %%
print('안녕', 'hello', '파이썬', 'python', sep= ',')
# Out:
# 안녕,hello,파이썬,python

# %%
def repeat_message(msg, n=1):   #n = default parameter 1 = default argument
    for _ in range(n):
        print(msg)

# %%
repeat_message('안녕하세요')
# Out:
# 안녕하세요

# %%
repeat_message('안녕하세요' , n = 3)    # 전달한 아규먼트(3)이 사용됨.
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %% [markdown]
# **(주의)** default parameter(기본값을 갖는 파라미터)들은 기본값을 갖지 않는 파라미터(들) 뒤에서만 선언 할 수 있음.
#
# default parameter를 기본값을 갖지 않는 파라미터보다 먼저 선언하면 문법 오류.

# %%
def test_success(x ,y = 1):
    pass

# %%
def tes_failure(x=1 , y ):
    pass
# Out:
#   File "<ipython-input-145-fbf09a9f23c3>", line 1
#     def tes_failure(x=1 , y ):
#                           ^
# SyntaxError: non-default argument follows default argument

# %%
def test(x = 0, y = 0):
    print(f'x = {x}, y = {y}')

# %%
test()
# Out:
# x = 0, y = 0

# %%
test(1)
# Out:
# x = 1, y = 0

# %%
test(0 , 2)
# Out:
# x = 0, y = 2

# %%
test(y=2)
# Out:
# x = 0, y = 2

# %%
test()

# %% [markdown]
# 함수를 호출할 때 아규먼트를 전달하는 방법
#
# *  ** positional argument**: 선언된 파라미터 순서대로 아규먼트(들)을 전달하는 방식
# *   **keyword argument**: `param = value`형식으로 아규먼트(들)을 전달하는 방식
#     *   keyword argument 방식을 사용할 때는 파라미터 선언순서를 지키지 않아도 됨.
#     *   **(주의)** 함수를 호출할 때 positional argument와 keyword argument를 함계사용하는 경우에는 반드시 positional argument 를 먼저 전달해야함. keyword argument를 positional argument보다 먼저 전달할 수 없음.

# %%
test(y=2,x=1)   # keyword argument 방식
# Out:
# x = 1, y = 2

# %%
test(100, y= -100)      #positional argument & keyword argument 방식을 함께 사용
# Out:
# x = 100, y = -100

# %%
test(x=1 , 0)       #keyword argument를 positional argument보다 먼저 사용하면 문법오류!
# Out:
#   File "<ipython-input-159-2b21d2a01334>", line 1
#     test(x=1 , 0)
#                 ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# # 가변길이 인수(variable-length argument)
#
# *   함수를 호출할 때 아규먼트를 몇 개를 전달해도 됨.
#     *   아규먼트를 한 개도 전달하지 않아도 됨.
# *   함수를 선언할 때 파라미터 이름 앞에  `*`를 사용하면 가변길이 인수.
# *   함수 내부에서 가변길이 인수는 튜플로 취급
#     *   가변길이 인수는 인덱스를 가짐.
#     *   가변길이 인수는 for-in 문장에서 사용할 수 있음.
# *   가변길이 인수는 keyword argument 방식으로 전달할 수 없음.
# *   함수를 선언할 때 가변길이 인수는 1개만 선언할 수 있음.
# *   가변길이 인수 뒤에서 선언된 파라미터(들)은 keyword argument 방식으로만 값을 전달할 수 있음.

# %%
print()
print('hello')
print('hello', '안녕')
# Out:
# hello
# hello 안녕

# %%
print('hello', '안녕', sep= ',')
# Out:
# hello,안녕

# %%
def add_all(*args):
    print(args)
    result = 0
    for x in args:
        result += x

    return result

# %%
add_all(1,2,3,45,2)
# Out:
# (1, 2, 3, 45, 2)
# 53

# %%
add_all(args=1, 2, 3, 4)        # 가변길이 인수는 keyword argument 방식을 사용할 수 없음.
# Out:
#   File "<ipython-input-171-2e20de98ded8>", line 1
#     add_all(args=1, 2, 3, 4)        # 가변길이 인수는 keyword argument 방식을 사용할 수 없음.
#                            ^
# SyntaxError: positional argument follows keyword argument

# %%
def test_var_args(x, *y):
    print(f'x = {x}, y = {y}')

# %%
test_var_args(1, 2)
test_var_args(1,2,3,4)
test_var_args(1)    #> 가변길이 인수는 값을 전달하지 않아도 됨.
# test_var_args()   #> 파라미터 x는 기본값이 없기 때문에 반즈시 값(아규먼트)를 전달해야함
test_var_args(x=1)
# test_var_args(x=1, 2,3,4,5,6) #> keyword argument가 positional argumet들보다 먼저 사용될 수 없음.
# Out:
# x = 1, y = (2,)
# x = 1, y = (2, 3, 4)
# x = 1, y = ()
# x = 1, y = ()

# %%
def test_var_args_error(*x , *y):       #* argument may appear only once
    pass
# Out:
#   File "<ipython-input-185-2d7705cda558>", line 1
#     def test_var_args_error(*x , *y):
#                                  ^
# SyntaxError: * argument may appear only once

# %%
# def test_var_args2(*x, y):        #

# %%
# test_var_args2(1,2,3)         #>missing 1 required keyword-only argument: 'y'
test_var_args2(1,2, y=3)        #> 파라미터 y에 값을 전달할 수 있는 방법은 오직 keyword argument 방식.

# %%
def fn(a, b, *, x, y, z):
    pass

# %%
fn(1,2,x= 3,y= 4,z= 5)

# %%
def calculate(*values, op):
    """
    op= '+'인 경우, values의 합계를 리턴.
    op='*'인 경우, values의 곱을 리턴.
    (예)
    calculate(1,2,3,'+') = 1 + 2 + 3
    calculate(1,2,3, '*') = 1 * 2 * 3
    values에 전달된 값이 없으면, op = '+'이면 0을 리턴, op='*'이면 1을 리턴.
    op의 값이 '+' 또는 '*'가 아니면 ValueError를 발생.
    """
    if op == '+':
        result = 0
        for x in values:
            result += x
    elif op == '*':
        result = 1
        for x in values:
            result *= x

    else:
        raise ValueError("아규먼트 op는 + 또는 *만 가능합니다.")

    return result

# %%
calculate(1,2,3,4,5, op = '+')
# Out:
# 15

# %%
calculate(1,2,3,4,5, op= '*')
# Out:
# 120

# %%
calculate(1,2,3,4,5, op= '/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-205-5c173fe7fd36> in <cell line: 0>()
# ----> 1 calculate(1,2,3,4,5, op= '/')
#
# <ipython-input-199-2acbb3f50640> in calculate(op, *values)
#      19
#      20     else:
# ---> 21         raise ValueError("아규먼트 op는 + 또는 *만 가능합니다.")
#      22
#      23     return result
#
# ValueError: 아규먼트 op는 + 또는 *만 가능합니다.

# %% [markdown]
# # 가변길이 키워드 아규먼트(Variable-length keyword argument)
#
# *   함수를 선언할 때 파라미터 이름 앞에 `**`를 사용.
# *   함수를 호출할 때, `parameter1 = value1, param2 = value2, ...` 형식으로 아규먼트들을 전달.
#     *   가변길이 인수 --> 전달하는 아규먼트 개수는 제한이 없음.
#     *   키워드 인수 --> 반드시 키워드(파라미터 이름)와 함께 아규먼트를 전달해야 함.
#         *   키워드는 자유롭게 만들 수 있음.
# *   함수 내부에서는 가변길이 키워드 아규먼트는 `dict` 타입 객체로 취급
#     *   키워드(파라미터 이름)는 dict의 키(key).
#     *   아규먼트(값)는 dict의 값(value)이 됨.
# *   가변길이 키워드 인수는 함수에서 오직 1개만 선언할 수 있음.

# %%
def test_kwargs(*args, **kwargs):
    print(f'args = {args}')
    print(f'kwargs = {kwargs}')

# %%
test_kwargs()
# Out:
# args = ()
# kwargs = {}

# %%
test_kwargs(1,2,'a','b')
# Out:
# args = (1, 2, 'a', 'b')
# kwargs = {}

# %%
test_kwargs(1,2,3, name= '오쌤', age= 16)
# Out:
# args = (1, 2, 3)
# kwargs = {'name': '오쌤', 'age': 16}

# %%
def test_kwargs2(**kwargs, *args):      #>arguments cannot follow var-keyword argument
    pass

# 가변길이 키워드 인수가 가변길이 인수보다 먼저 선언 될 수는 없다.
# Out:
#   File "<ipython-input-212-1641413f0308>", line 1
#     def test_kwargs2(**kwargs, *args):
#                                ^
# SyntaxError: arguments cannot follow var-keyword argument

# %%
def make_student_info(id, name, **kwargs):
    student = {'id': id, 'name': name}
    print(kwargs)
    for k, v in kwargs.items():
        if k in ('email', 'phone'):
            student[k] = v

        # else:
        #     raise TypeError(f'사용할 수 없는 키워드: {k}')


    return student

# %%
make_student_info(1, '홍길동')
# Out:
# {}
# {'id': 1, 'name': '홍길동'}

# %%
make_student_info(1100, 'Scott', email = 'scottking@itwill.com')
# Out:
# {'email': 'scottking@itwill.com'}
# {'id': 1100, 'name': 'Scott', 'email': 'scottking@itwill.com'}

# %%
make_student_info(2000, 'king',
                  phone = '010-0000-2341',
                  email = 'king@itwill.com',
                  dept  = '강의장 10',
                  grade = 3)
# Out:
# {'phone': '010-0000-2341', 'email': 'king@itwill.com', 'dept': '강의장 10', 'grade': 3}
# {'id': 2000,
#  'name': 'king',
#  'phone': '010-0000-2341',
#  'email': 'king@itwill.com'}
