# %% [markdown]
# github의 exam.csv 파일을 다운로드.
#
# Colab 연결(세션 활성화).
#
# Colab에 Google Drive 마운트(mount, 연결).
#
# 개인 계정의 Google Drive에 exam.csv 파일을 업로드.
#
# exam.csv 파일을 open
#
# 파일의 첫번째 줄은 컬럼 이름들이기 때문에, 첫번째 줄은 읽고 무시.
#
# 파일의 두번째 줄부터 파일 끝(EOF)까지 반복.
#
# 각 줄에서 읽은 내용을 쉼표(,)로 분리한 리스트를 빈 리스트에 append.
# [['1', '1', '50', '98', '50'], ['2', '1', '60', '97', '60'], ...]
#
# 위에서 만들어진 2차원 리스트는 문자열들을 저장하고 있는 리스트이기 때문에, 리스트의 모든 값들을 정수(int)로 변환
#
# [[1, 1, 50, 98, 50], [2, 1, 60, 97, 60], ...]
#
# 수학 점수들로만 이루어진 1차원 리스트를 만듦.
#
# [50, 60, ...]
#
# 수학 점수의 최댓값, 최솟값, 평균 출력.
#
# 1반 학생들의 수학 점수 총점, 평균, 최댓값, 최솟값 출력

# %% [markdown]
# ##  내 방식

# %%
exam = '/content/drive/MyDrive/Colab Notebooks/lab_python/exam.csv'
exam
# Out:
# '/content/drive/MyDrive/Colab Notebooks/lab_python/exam.csv'

# %%
with open(exam) as f:
    f.readline()
    for line in f:
        print(line)
# Out:
# 1,1,50,98,50
#
# 2,1,60,97,60
#
# 3,1,45,86,78
#
# 4,1,30,98,58
#
# 5,2,25,80,65
#
# 6,2,50,89,98
#
# 7,2,80,90,45
#
# 8,2,90,78,25
#
# 9,3,20,98,15
#
# 10,3,50,98,45
#
# 11,3,65,65,65
#
# 12,3,45,85,32
#
# 13,4,46,98,65
#
# 14,4,48,87,12
#
# 15,4,75,56,78
#
# 16,4,58,98,65
#
# 17,5,65,68,98
#
# 18,5,80,78,90
#
# 19,5,89,68,87
#
# 20,5,78,83,58

# %%
exam_list =[]

# %%
with open(exam) as f:
    f.readline()
    for line in f:
        exam_list.append(line.split(','))

# %%
exam_list
# Out:
# [['1', '1', '50', '98', '50\n'],
#  ['2', '1', '60', '97', '60\n'],
#  ['3', '1', '45', '86', '78\n'],
#  ['4', '1', '30', '98', '58\n'],
#  ['5', '2', '25', '80', '65\n'],
#  ['6', '2', '50', '89', '98\n'],
#  ['7', '2', '80', '90', '45\n'],
#  ['8', '2', '90', '78', '25\n'],
#  ['9', '3', '20', '98', '15\n'],
#  ['10', '3', '50', '98', '45\n'],
#  ['11', '3', '65', '65', '65\n'],
#  ['12', '3', '45', '85', '32\n'],
#  ['13', '4', '46', '98', '65\n'],
#  ['14', '4', '48', '87', '12\n'],
#  ['15', '4', '75', '56', '78\n'],
#  ['16', '4', '58', '98', '65\n'],
#  ['17', '5', '65', '68', '98\n'],
#  ['18', '5', '80', '78', '90\n'],
#  ['19', '5', '89', '68', '87\n'],
#  ['20', '5', '78', '83', '58\n']]

# %%
int_exam_list =[[int(s.strip()) for s in x]for x in exam_list]

# %%
int_exam_list
# Out:
# [[1, 1, 50, 98, 50],
#  [2, 1, 60, 97, 60],
#  [3, 1, 45, 86, 78],
#  [4, 1, 30, 98, 58],
#  [5, 2, 25, 80, 65],
#  [6, 2, 50, 89, 98],
#  [7, 2, 80, 90, 45],
#  [8, 2, 90, 78, 25],
#  [9, 3, 20, 98, 15],
#  [10, 3, 50, 98, 45],
#  [11, 3, 65, 65, 65],
#  [12, 3, 45, 85, 32],
#  [13, 4, 46, 98, 65],
#  [14, 4, 48, 87, 12],
#  [15, 4, 75, 56, 78],
#  [16, 4, 58, 98, 65],
#  [17, 5, 65, 68, 98],
#  [18, 5, 80, 78, 90],
#  [19, 5, 89, 68, 87],
#  [20, 5, 78, 83, 58]]

# %%
math_exam = []
for x in int_exam_list:
    math_exam.append(x[2])
math_exam
# Out:
# [50,
#  60,
#  45,
#  30,
#  25,
#  50,
#  80,
#  90,
#  20,
#  50,
#  65,
#  45,
#  46,
#  48,
#  75,
#  58,
#  65,
#  80,
#  89,
#  78]

# %%
max(math_exam)
# Out:
# 90

# %%
min(math_exam)
# Out:
# 20

# %%
mean = sum(math_exam) / 20
mean
# Out:
# 57.45

# %% [markdown]
# 1반 학생들의 수학 점수 총점, 평균, 최댓값, 최솟값 출력

# %%
class1_exam = []
for x in int_exam_list:
    if x[1] == 1:
        class1_exam.append(x[2])
        class1_exam.append(x[3])
        class1_exam.append(x[4])

class1_exam
# Out:
# [50, 98, 50, 60, 97, 60, 45, 86, 78, 30, 98, 58]

# %%
len(class1_exam)
# Out:
# 12

# %%
sum_class1 = sum(class1_exam)
sum_class1
# Out:
# 810

# %%
mean = sum_class1 / len(class1_exam)
mean
# Out:
# 67.5

# %%
max_class1 = max(class1_exam)
max_class1
# Out:
# 98

# %%
min_class1 = min(class1_exam)
min_class1
# Out:
# 30

# %% [markdown]
# 1반 ~ 5반 수학 평균 점수를 출력

# %%
class1_math = []
class2_math = []
class3_math = []
class4_math = []
class5_math = []

for x in int_exam_list:
    if x[1] ==1:
        class1_math.append(x[2])
    elif x[1] ==2:
        class2_math.append(x[2])
    elif x[1] ==3:
        class1_math.append(x[2])
    elif x[1] ==4:
        class1_math.append(x[2])
    elif x[1] ==5:
        class1_math.append(x[2])

class1_math
# Out:
# [50, 60, 45, 30, 20, 50, 65, 45, 46, 48, 75, 58, 65, 80, 89, 78]

# %% [markdown]
# ## 오쌤 방식

# %%
file_path  = '/content/drive/MyDrive/Colab Notebooks/lab_python/exam.csv'

# %%
with open(file_path) as f:
    f.readline()        # 파일에서 첫번째 라인을 읽음.
    exam = []           # csv 파일의 내용을 저장할 빈 리스트.
    for line in f:      # 열린 파일 f에서 두번쨰 줄부터 끝까지 반복하면서 한줄씩 읽음.
        exam.append(line.strip().split(','))
exam
# Out:
# [['1', '1', '50', '98', '50'],
#  ['2', '1', '60', '97', '60'],
#  ['3', '1', '45', '86', '78'],
#  ['4', '1', '30', '98', '58'],
#  ['5', '2', '25', '80', '65'],
#  ['6', '2', '50', '89', '98'],
#  ['7', '2', '80', '90', '45'],
#  ['8', '2', '90', '78', '25'],
#  ['9', '3', '20', '98', '15'],
#  ['10', '3', '50', '98', '45'],
#  ['11', '3', '65', '65', '65'],
#  ['12', '3', '45', '85', '32'],
#  ['13', '4', '46', '98', '65'],
#  ['14', '4', '48', '87', '12'],
#  ['15', '4', '75', '56', '78'],
#  ['16', '4', '58', '98', '65'],
#  ['17', '5', '65', '68', '98'],
#  ['18', '5', '80', '78', '90'],
#  ['19', '5', '89', '68', '87'],
#  ['20', '5', '78', '83', '58']]

# %%
for i, row in enumerate(exam):
    for j, x in enumerate(row):
        exam[i][j] = int(x)

exam
# Out:
# [[1, 1, 50, 98, 50],
#  [2, 1, 60, 97, 60],
#  [3, 1, 45, 86, 78],
#  [4, 1, 30, 98, 58],
#  [5, 2, 25, 80, 65],
#  [6, 2, 50, 89, 98],
#  [7, 2, 80, 90, 45],
#  [8, 2, 90, 78, 25],
#  [9, 3, 20, 98, 15],
#  [10, 3, 50, 98, 45],
#  [11, 3, 65, 65, 65],
#  [12, 3, 45, 85, 32],
#  [13, 4, 46, 98, 65],
#  [14, 4, 48, 87, 12],
#  [15, 4, 75, 56, 78],
#  [16, 4, 58, 98, 65],
#  [17, 5, 65, 68, 98],
#  [18, 5, 80, 78, 90],
#  [19, 5, 89, 68, 87],
#  [20, 5, 78, 83, 58]]

# %%
# math = []
# for row in exam:
#     math.append(row[2])
math = [row[2] for row in exam]
print(math)
# Out:
# [50, 60, 45, 30, 25, 50, 80, 90, 20, 50, 65, 45, 46, 48, 75, 58, 65, 80, 89, 78]

# %%
print('math max: ', max(math))
print('math min: ', min(math))
print('math mean: ', sum(math) / len(math))
# Out:
# math max:  90
# math min:  20
# math mean:  57.45

# %%
eng = [row[3] for row in exam]
print(eng)
# Out:
# [98, 97, 86, 98, 80, 89, 90, 78, 98, 98, 65, 85, 98, 87, 56, 98, 68, 78, 68, 83]

# %%
print('eng max: ', max(eng))
print('eng min: ', min(eng))
print('eng mean: ', sum(eng) / len(eng))
# Out:
# eng max:  98
# eng min:  56
# eng mean:  84.9

# %%
# math_class1 = []  # 1반(class=1) 수학 점수를 저장하기 위한 리스트
# for row in exam:
#     if row[1] == 1:  # class 컬럼의 값이 1이면
#         math_class1.append(row[2])  # math 컬럼의 값을 리스트에 추가.
math_class1 = [row[2] for row in exam if row[1] == 1]

print(math_class1)
# Out:
# [50, 60, 45, 30]

# %%
print('1반 수학 총점:', sum(math_class1))
print('1반 수학 평균:', sum(math_class1) / len(math_class1))
print('1반 수학 최댓값:', max(math_class1))
print('1반 수학 최솟값:', min(math_class1))
# Out:
# 1반 수학 총점: 185
# 1반 수학 평균: 46.25
# 1반 수학 최댓값: 60
# 1반 수학 최솟값: 30

# %%
for cls in range(1,6):
    math_by_class = [row[2] for row in exam if row[1] == cls]
    print(f'{cls}반: {math_by_class}')
    mean =sum(math_by_class) / len(math_by_class)
    print(f'      평균: {mean}')
# Out:
# 1반: [50, 60, 45, 30]
#       평균: 46.25
# 2반: [25, 50, 80, 90]
#       평균: 61.25
# 3반: [20, 50, 65, 45]
#       평균: 45.0
# 4반: [46, 48, 75, 58]
#       평균: 56.75
# 5반: [65, 80, 89, 78]
#       평균: 78.0

# %% [markdown]
# ## class 선언

# %%
class Student:
    def __init__(self, id, cls, math, english, science):
        self.id = int(id)
        self.cls = int(cls)
        self.math = int(math)
        self.english = int(english)
        self.science = int(science)

    def __repr__(self):
        return f'Student(id={self.id}, class={self.cls}, math={self.math}, english={self.english}, science={self.science})'

# %%
s = Student(1,1,'50','70','80')
s
# Out:
# Student(id=1, class=1, math=50, english=70, science=80)

# %%
exam2 = []      # csv 파일에서 읽은 데이터를 저장하기 위한 리스트
with open(file_path) as f:
    f.readline()
    for line in f:
        row = line.strip().split(sep= ',')
        student = Student(row[0], row[1], row[2], row[3],row[4])
        exam2.append(student)

exam2
# Out:
# [Student(id=1, class=1, math=50, english=98, science=50),
#  Student(id=2, class=1, math=60, english=97, science=60),
#  Student(id=3, class=1, math=45, english=86, science=78),
#  Student(id=4, class=1, math=30, english=98, science=58),
#  Student(id=5, class=2, math=25, english=80, science=65),
#  Student(id=6, class=2, math=50, english=89, science=98),
#  Student(id=7, class=2, math=80, english=90, science=45),
#  Student(id=8, class=2, math=90, english=78, science=25),
#  Student(id=9, class=3, math=20, english=98, science=15),
#  Student(id=10, class=3, math=50, english=98, science=45),
#  Student(id=11, class=3, math=65, english=65, science=65),
#  Student(id=12, class=3, math=45, english=85, science=32),
#  Student(id=13, class=4, math=46, english=98, science=65),
#  Student(id=14, class=4, math=48, english=87, science=12),
#  Student(id=15, class=4, math=75, english=56, science=78),
#  Student(id=16, class=4, math=58, english=98, science=65),
#  Student(id=17, class=5, math=65, english=68, science=98),
#  Student(id=18, class=5, math=80, english=78, science=90),
#  Student(id=19, class=5, math=89, english=68, science=87),
#  Student(id=20, class=5, math=78, english=83, science=58)]

# %%
math2 = [s.math for s in exam2]      # exam2에서 수학점수들만 선택해서 저장
print(math2)
# Out:
# [50, 60, 45, 30, 25, 50, 80, 90, 20, 50, 65, 45, 46, 48, 75, 58, 65, 80, 89, 78]

# %%
english2 = [s.english for s in exam2]
print(english2)
# Out:
# [98, 97, 86, 98, 80, 89, 90, 78, 98, 98, 65, 85, 98, 87, 56, 98, 68, 78, 68, 83]

# %%
science2 = [s.science for s in exam2]
print(science2)
# Out:
# [50, 60, 78, 58, 65, 98, 45, 25, 15, 45, 65, 32, 65, 12, 78, 65, 98, 90, 87, 58]

# %% [markdown]
# 각반의 수학 점수 평균

# %%
for cls in range(1,6):
    # math_by_class = []
    # for s in exam2:
    #     if s.cls == cls:
    #         math_by_class.append(s.math)
    math_by_class = [s.math for s in exam2 if s.cls == cls]
    mean = sum(math_by_class) / len(math_by_class)
    print(f'{cls}반 수학 평균: {mean}')
# Out:
# 1반 수학 평균: 46.25
# 2반 수학 평균: 61.25
# 3반 수학 평균: 45.0
# 4반 수학 평균: 56.75
# 5반 수학 평균: 78.0

# %%
for cls in range(1,6):

    english_by_class = [s.english for s in exam2 if s.cls == cls]
    mean = sum(english_by_class) / len(english_by_class)
    print(f'{cls}반 영어 평균: {mean}')
# Out:
# 1반 영어 평균: 94.75
# 2반 영어 평균: 84.25
# 3반 영어 평균: 86.5
# 4반 영어 평균: 84.75
# 5반 영어 평균: 74.25

# %%
def subject_mean_by_class(cls, subject):
    """
    반(cls) 별 과목(subject)의 평균 점수를 리턴.
    (예) subject_mean_by_class(1, 'math') -> 1반 수학 점수 평균을 리턴.

    @param cls: 반 번호. 1 ~ 5.
    @param subject: 과목 이름. math, english, science
    @return 해당 cls의 해당 subject의 평균.
    """
